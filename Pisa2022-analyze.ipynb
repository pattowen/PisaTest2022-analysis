# %%
import os
import pandas as pd

# %% [markdown]
# Prepare 2022 PISA Dataset

# %%
pisa2022_df = pd.read_sas(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\cy08msp_stu_qqq.sas7bdat", encoding='cp1252')
pisa2022_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV4MPRE  PV5MPRE  PV6MPRE  PV7MPRE  PV8MPRE  \
# 0         800.0   0.0  ...  203.029  219.817  331.017  223.752  305.671
# 1         800.0   0.0  ...  321.405  320.452  284.836  364.565  304.044
# 2         800.0   0.0  ...  376.019  285.901  289.896  338.469  316.296
# 3         800.0   0.0  ...  303.422  327.793  165.575  246.156  238.322
# 4         800.0   0.0  ...  514.739  539.850  461.793  514.465  510.462
# ...         ...   ...  ...      ...      ...      ...      ...      ...
# 613739  86000.0   0.0  ...  306.551  271.135  386.969  376.271  368.287
# 613740  86000.0   0.0  ...  335.952  232.583  179.328  233.470  203.001
# 613741  86000.0   0.0  ...  451.614  432.586  387.329  456.236  424.790
# 613742  86000.0   0.0  ...  272.346  317.838  248.165  405.860  364.173
# 613743  86000.0   0.0  ...  416.631  337.422  370.817  395.176  412.317
#
#         PV9MPRE  PV10MPRE    SENWT           VER_DAT      i
# 0       230.156   289.436  0.55561  03MAY23:10:11:25  218.0
# 1       347.626   352.269  0.76431  03MAY23:10:11:25  218.0
# 2       324.361   343.351  1.37877  03MAY23:10:11:25  218.0
# 3       275.860   227.466  1.49361  03MAY23:10:11:26  218.0
# 4       490.537   503.793  0.65249  03MAY23:10:11:26  218.0
# ...         ...       ...      ...               ...    ...
# 613739  395.329   278.263  0.71987  02MAY23:13:18:15  218.0
# 613740  254.340   233.187  0.65541  02MAY23:13:18:13  218.0
# 613741  408.986   460.542  0.67910  02MAY23:13:18:13  218.0
# 613742  346.663   341.668  0.68618  02MAY23:13:18:14  218.0
# 613743  390.490   439.211  0.67910  02MAY23:13:18:13  218.0
#
# [613744 rows x 1279 columns]

# %%
pisa2022_df.dtypes
# Out:
# CNT              object
# CNTRYID         float64
# CNTSCHID        float64
# CNTSTUID        float64
# CYC              object
# NatCen           object
# STRATUM          object
# SUBNATIO         object
# REGION          float64
# OECD            float64
# ADMINMODE       float64
# LANGTEST_QQQ    float64
# LANGTEST_COG    float64
# LANGTEST_PAQ    float64
# Option_CT       float64
# Option_FL       float64
# Option_ICTQ     float64
# Option_WBQ      float64
# Option_PQ       float64
# Option_TQ       float64
# Option_UH       float64
# BOOKID          float64
# ST001D01T       float64
# ST003D02T       float64
# ST003D03T       float64
# ST004D01T       float64
# ST250Q01JA      float64
# ST250Q02JA      float64
# ST250Q03JA      float64
# ST250Q04JA      float64
# ST250Q05JA      float64
# ST250D06JA       object
# ST250D07JA       object
# ST251Q01JA      float64
# ST251Q02JA      float64
# ST251Q03JA      float64
# ST251Q04JA      float64
# ST251Q06JA      float64
# ST251Q07JA      float64
# ST251D08JA       object
# ST251D09JA       object
# ST253Q01JA      float64
# ST254Q01JA      float64
# ST254Q02JA      float64
# ST254Q03JA      float64
# ST254Q04JA      float64
# ST254Q05JA      float64
# ST254Q06JA      float64
# ST255Q01JA      float64
# ST256Q01JA      float64
# ST256Q02JA      float64
# ST256Q03JA      float64
# ST256Q06JA      float64
# ST256Q07JA      float64
# ST256Q08JA      float64
# ST256Q09JA      float64
# ST256Q10JA      float64
# ST230Q01JA      float64
# ST005Q01JA      float64
# ST006Q01JA      float64
# ST006Q02JA      float64
# ST006Q03JA      float64
# ST006Q04JA      float64
# ST006Q05JA      float64
# ST007Q01JA      float64
# ST008Q01JA      float64
# ST008Q02JA      float64
# ST008Q03JA      float64
# ST008Q04JA      float64
# ST008Q05JA      float64
# ST258Q01JA      float64
# ST259Q01JA      float64
# ST259Q02JA      float64
# ST019AQ01T      float64
# ST019BQ01T      float64
# ST019CQ01T      float64
# ST021Q01TA      float64
# ST022Q01TA      float64
# ST226Q01JA      float64
# ST125Q01NA      float64
# ST126Q01TA      float64
# ST127Q01TA      float64
# ST127Q02TA      float64
# ST127Q03TA      float64
# ST260Q01JA      float64
# ST260Q02JA      float64
# ST260Q03JA      float64
# ST261Q01JA      float64
# ST261Q02JA      float64
# ST261Q03JA      float64
# ST261Q04JA      float64
# ST261Q05JA      float64
# ST261Q06JA      float64
# ST261Q07JA      float64
# ST261Q08JA      float64
# ST261Q09JA      float64
# ST261Q10JA      float64
# ST261Q11JA      float64
# ST062Q01TA      float64
# ST062Q02TA      float64
# ST062Q03TA      float64
# ST267Q01JA      float64
# ST267Q02JA      float64
# ST267Q03JA      float64
# ST267Q04JA      float64
# ST267Q05JA      float64
# ST267Q06JA      float64
# ST267Q07JA      float64
# ST267Q08JA      float64
# ST034Q01TA      float64
# ST034Q02TA      float64
# ST034Q03TA      float64
# ST034Q04TA      float64
# ST034Q05TA      float64
# ST034Q06TA      float64
# ST038Q03NA      float64
# ST038Q04NA      float64
# ST038Q05NA      float64
# ST038Q06NA      float64
# ST038Q07NA      float64
# ST038Q08NA      float64
# ST038Q09JA      float64
# ST038Q10JA      float64
# ST038Q11JA      float64
# ST265Q01JA      float64
# ST265Q02JA      float64
# ST265Q03JA      float64
# ST265Q04JA      float64
# ST266Q01JA      float64
# ST266Q02JA      float64
# ST266Q03JA      float64
# ST266Q04JA      float64
# ST266Q05JA      float64
# ST294Q01JA      float64
# ST294Q02JA      float64
# ST294Q03JA      float64
# ST294Q04JA      float64
# ST294Q05JA      float64
# ST295Q01JA      float64
# ST295Q02JA      float64
# ST295Q03JA      float64
# ST295Q04JA      float64
# ST295Q05JA      float64
# ST326Q01JA      float64
# ST326Q02JA      float64
# ST326Q03JA      float64
# ST326Q04JA      float64
# ST326Q05JA      float64
# ST326Q06JA      float64
# ST326Q07JA      float64
# ST326Q08JA      float64
# ST326Q09JA      float64
# ST326Q10JA      float64
# ST326Q11JA      float64
# ST326Q12JA      float64
# ST322Q01JA      float64
# ST322Q02JA      float64
# ST322Q03JA      float64
# ST322Q04JA      float64
# ST322Q06JA      float64
# ST322Q07JA      float64
# ST307Q01JA      float64
# ST307Q02JA      float64
# ST307Q03JA      float64
# ST307Q04JA      float64
# ST307Q05JA      float64
# ST307Q06JA      float64
# ST307Q07JA      float64
# ST307Q08JA      float64
# ST307Q09JA      float64
# ST307Q10JA      float64
# ST309Q01JA      float64
# ST309Q02JA      float64
# ST309Q03JA      float64
# ST309Q04JA      float64
# ST309Q05JA      float64
# ST309Q06JA      float64
# ST309Q07JA      float64
# ST309Q08JA      float64
# ST309Q09JA      float64
# ST309Q10JA      float64
# ST301Q01JA      float64
# ST301Q02JA      float64
# ST301Q03JA      float64
# ST301Q04JA      float64
# ST301Q05JA      float64
# ST301Q06JA      float64
# ST301Q07JA      float64
# ST301Q08JA      float64
# ST301Q09JA      float64
# ST301Q10JA      float64
# ST343Q01JA      float64
# ST343Q02JA      float64
# ST343Q03JA      float64
# ST343Q04JA      float64
# ST343Q05JA      float64
# ST343Q06JA      float64
# ST343Q07JA      float64
# ST343Q08JA      float64
# ST343Q09JA      float64
# ST343Q10JA      float64
# ST311Q01JA      float64
# ST311Q02JA      float64
# ST311Q03JA      float64
# ST311Q04JA      float64
# ST311Q05JA      float64
# ST311Q06JA      float64
# ST311Q07JA      float64
# ST311Q08JA      float64
# ST311Q09JA      float64
# ST311Q10JA      float64
# ST315Q01JA      float64
# ST315Q02JA      float64
# ST315Q03JA      float64
# ST315Q04JA      float64
# ST315Q05JA      float64
# ST315Q06JA      float64
# ST315Q07JA      float64
# ST315Q08JA      float64
# ST315Q09JA      float64
# ST315Q10JA      float64
# ST303Q01JA      float64
# ST303Q02JA      float64
# ST303Q03JA      float64
# ST303Q04JA      float64
# ST303Q05JA      float64
# ST303Q06JA      float64
# ST303Q07JA      float64
# ST303Q08JA      float64
# ST305Q01JA      float64
# ST305Q02JA      float64
# ST305Q03JA      float64
# ST305Q04JA      float64
# ST305Q05JA      float64
# ST305Q06JA      float64
# ST305Q07JA      float64
# ST305Q08JA      float64
# ST305Q09JA      float64
# ST305Q10JA      float64
# ST345Q01JA      float64
# ST345Q02JA      float64
# ST345Q03JA      float64
# ST345Q04JA      float64
# ST345Q05JA      float64
# ST345Q06JA      float64
# ST345Q07JA      float64
# ST345Q08JA      float64
# ST345Q09JA      float64
# ST345Q10JA      float64
# ST313Q01JA      float64
# ST313Q02JA      float64
# ST313Q03JA      float64
# ST313Q04JA      float64
# ST313Q05JA      float64
# ST313Q06JA      float64
# ST313Q07JA      float64
# ST313Q08JA      float64
# ST313Q09JA      float64
# ST313Q10JA      float64
# ST263Q02JA      float64
# ST263Q04JA      float64
# ST263Q06JA      float64
# ST263Q08JA      float64
# ST016Q01NA      float64
# ST059Q01TA      float64
# ST059Q02JA      float64
# ST296Q01JA      float64
# ST296Q02JA      float64
# ST296Q03JA      float64
# ST296Q04JA      float64
# ST272Q01JA      float64
# ST273Q01JA      float64
# ST273Q02JA      float64
# ST273Q03JA      float64
# ST273Q04JA      float64
# ST273Q05JA      float64
# ST273Q06JA      float64
# ST273Q07JA      float64
# ST270Q01JA      float64
# ST270Q02JA      float64
# ST270Q03JA      float64
# ST270Q04JA      float64
# ST285Q01JA      float64
# ST285Q02JA      float64
# ST285Q03JA      float64
# ST285Q04JA      float64
# ST285Q05JA      float64
# ST285Q06JA      float64
# ST285Q07JA      float64
# ST285Q08JA      float64
# ST285Q09JA      float64
# ST283Q01JA      float64
# ST283Q02JA      float64
# ST283Q03JA      float64
# ST283Q04JA      float64
# ST283Q05JA      float64
# ST283Q06JA      float64
# ST283Q07JA      float64
# ST283Q08JA      float64
# ST283Q09JA      float64
# ST275Q01WA      float64
# ST275Q02WA      float64
# ST275Q03WA      float64
# ST275Q04WA      float64
# ST275Q05WA      float64
# ST275Q06WA      float64
# ST275Q07WA      float64
# ST275Q08WA      float64
# ST275Q09WA      float64
# ST276Q01JA      float64
# ST276Q02JA      float64
# ST276Q03JA      float64
# ST276Q04JA      float64
# ST276Q05JA      float64
# ST276Q06JA      float64
# ST276Q07JA      float64
# ST276Q08JA      float64
# ST276Q09JA      float64
# ST276Q10JA      float64
# ST268Q01JA      float64
# ST268Q02JA      float64
# ST268Q03JA      float64
# ST268Q04JA      float64
# ST268Q05JA      float64
# ST268Q06JA      float64
# ST268Q07JA      float64
# ST268Q08JA      float64
# ST268Q09JA      float64
# ST290Q01WA      float64
# ST290Q02WA      float64
# ST290Q03WA      float64
# ST290Q04WA      float64
# ST290Q05WA      float64
# ST290Q06WA      float64
# ST290Q07WA      float64
# ST290Q08WA      float64
# ST290Q09WA      float64
# ST291Q01JA      float64
# ST291Q02JA      float64
# ST291Q03JA      float64
# ST291Q04JA      float64
# ST291Q05JA      float64
# ST291Q06JA      float64
# ST291Q07JA      float64
# ST291Q08JA      float64
# ST291Q09JA      float64
# ST291Q10JA      float64
# ST289Q01WA      float64
# ST289Q02JA      float64
# ST289Q03WA      float64
# ST289Q04JA      float64
# ST289Q05WA      float64
# ST289Q06JA      float64
# ST289Q07JA      float64
# ST289Q08WA      float64
# ST289Q09WA      float64
# ST289Q10WA      float64
# ST289Q11WA      float64
# ST289Q14JA      float64
# ST293Q01JA      float64
# ST293Q02JA      float64
# ST293Q03JA      float64
# ST293Q04JA      float64
# ST293Q05JA      float64
# ST293Q06JA      float64
# ST293Q07JA      float64
# ST293Q08JA      float64
# ST293Q09JA      float64
# ST292Q01JA      float64
# ST292Q02JA      float64
# ST292Q03JA      float64
# ST292Q04JA      float64
# ST292Q05JA      float64
# ST292Q06JA      float64
# ST297Q01JA      float64
# ST297Q03JA      float64
# ST297Q05JA      float64
# ST297Q06JA      float64
# ST297Q07JA      float64
# ST297Q09JA      float64
# ST334Q01JA      float64
# ST334Q02JA      float64
# ST334Q03JA      float64
# ST334Q04JA      float64
# ST334Q05JA      float64
# ST334Q06JA      float64
# ST334Q07JA      float64
# ST334Q08JA      float64
# ST334Q09JA      float64
# ST334Q10JA      float64
# ST335Q01JA      float64
# ST335Q02JA      float64
# ST335Q03JA      float64
# ST335Q05JA      float64
# ST335Q06JA      float64
# ST335Q07JA      float64
# ST336Q01JA      float64
# ST336Q03JA      float64
# ST336Q04JA      float64
# ST336Q05JA      float64
# ST336Q06JA      float64
# ST336Q07JA      float64
# ST337Q01JA      float64
# ST337Q02JA      float64
# ST337Q03JA      float64
# ST337Q04JA      float64
# ST337Q05JA      float64
# ST337Q06JA      float64
# ST337Q07JA      float64
# ST337Q08JA      float64
# ST338Q01JA      float64
# ST338Q02JA      float64
# ST338Q03JA      float64
# ST338Q04JA      float64
# ST338Q05JA      float64
# ST338Q06JA      float64
# ST338Q07JA      float64
# ST338Q08JA      float64
# ST339Q04JA      float64
# ST339Q06JA      float64
# ST340Q01JA      float64
# ST340Q02JA      float64
# ST340Q03JA      float64
# ST340Q04JA      float64
# ST340Q05JA      float64
# ST340Q06JA      float64
# ST340Q07JA      float64
# ST340Q08JA      float64
# ST340Q09JA      float64
# ST340Q10JA      float64
# ST341Q01JA      float64
# ST341Q02JA      float64
# ST341Q03JA      float64
# ST341Q04JA      float64
# ST341Q05JA      float64
# ST342Q01JA      float64
# ST342Q02JA      float64
# ST342Q03JA      float64
# ST342Q04JA      float64
# ST342Q06JA      float64
# ST342Q07JA      float64
# ST342Q08JA      float64
# ST300Q01JA      float64
# ST300Q02JA      float64
# ST300Q03JA      float64
# ST300Q04JA      float64
# ST300Q05JA      float64
# ST300Q06JA      float64
# ST300Q07JA      float64
# ST300Q08JA      float64
# ST300Q09JA      float64
# ST300Q10JA      float64
# ST327Q01JA      float64
# ST327Q02JA      float64
# ST327Q03JA      float64
# ST327Q04JA      float64
# ST327Q05JA      float64
# ST327Q06JA      float64
# ST327Q07JA      float64
# ST327Q08JA      float64
# ST330Q01WA      float64
# ST330Q02WA      float64
# ST330Q03WA      float64
# ST330Q04WA      float64
# ST330Q05WA      float64
# ST330Q06WA      float64
# ST330Q07WA      float64
# ST330Q08WA      float64
# ST330Q09WA      float64
# ST330Q11WA      float64
# ST330D10WA       object
# ST324Q02JA      float64
# ST324Q04JA      float64
# ST324Q05JA      float64
# ST324Q07JA      float64
# ST324Q10JA      float64
# ST324Q11JA      float64
# ST324Q12JA      float64
# ST324Q13JA      float64
# ST324Q14JA      float64
# ST347Q01JA      float64
# ST347Q02JA      float64
# ST348Q01JA      float64
# ST348Q02JA      float64
# ST348Q03JA      float64
# ST348Q04JA      float64
# ST348Q05JA      float64
# ST348Q06JA      float64
# ST348Q07JA      float64
# ST348Q08JA      float64
# ST349Q01JA      float64
# ST350Q01JA      float64
# ST351Q01JA      float64
# ST351Q02JA      float64
# ST351Q03JA      float64
# ST351Q04JA      float64
# ST351Q05JA      float64
# ST351Q06JA      float64
# ST351Q07JA      float64
# ST351Q08JA      float64
# ST352Q01JA      float64
# ST352Q02JA      float64
# ST352Q03JA      float64
# ST352Q04JA      float64
# ST352Q05JA      float64
# ST352Q06JA      float64
# ST352Q07JA      float64
# ST352Q08JA      float64
# ST353Q01JA      float64
# ST353Q02JA      float64
# ST353Q03JA      float64
# ST353Q04JA      float64
# ST353Q05JA      float64
# ST353Q06JA      float64
# ST353Q07JA      float64
# ST353Q08JA      float64
# ST354Q01JA      float64
# ST354Q02JA      float64
# ST354Q03JA      float64
# ST354Q04JA      float64
# ST354Q05JA      float64
# ST354Q06JA      float64
# ST354Q07JA      float64
# ST354Q08JA      float64
# ST354Q09JA      float64
# ST354Q10JA      float64
# ST355Q01JA      float64
# ST355Q02JA      float64
# ST355Q03JA      float64
# ST355Q04JA      float64
# ST355Q05JA      float64
# ST355Q06JA      float64
# ST355Q07JA      float64
# ST355Q08JA      float64
# ST356Q01JA      float64
# ST331Q01JA      float64
# ST331Q02JA      float64
# ST331Q03JA      float64
# FL150Q01TA      float64
# FL150Q02TA      float64
# FL150Q03TA      float64
# FL164Q01HA      float64
# FL164Q02HA      float64
# FL164Q03HA      float64
# FL164Q04HA      float64
# FL164Q05HA      float64
# FL164Q06HA      float64
# FL164Q07HA      float64
# FL164Q08HA      float64
# FL164Q09HA      float64
# FL164Q10HA      float64
# FL164Q11HA      float64
# FL164Q12HA      float64
# FL164Q13HA      float64
# FL164Q14HA      float64
# FL164Q15HA      float64
# FL164Q16HA      float64
# FL166Q01HA      float64
# FL166Q02HA      float64
# FL166Q03HA      float64
# FL166Q05HA      float64
# FL166Q06HA      float64
# FL166Q07HA      float64
# FL174Q01JA      float64
# FL174Q02JA      float64
# FL174Q03JA      float64
# FL174Q04JA      float64
# FL174Q05JA      float64
# FL174Q06JA      float64
# FL174Q07JA      float64
# FL167Q01HA      float64
# FL167Q02HA      float64
# FL167Q06JA      float64
# FL167Q03HA      float64
# FL167Q04HA      float64
# FL167Q05HA      float64
# FL167Q07JA      float64
# FL170Q01JA      float64
# FL170Q02JA      float64
# FL170Q03JA      float64
# FL170Q04JA      float64
# FL170Q05JA      float64
# FL170Q06JA      float64
# FL170Q07JA      float64
# FL159Q01HA      float64
# FL159Q02HA      float64
# FL159Q03HA      float64
# FL159Q04HA      float64
# FL160Q01HA      float64
# FL160Q02HA      float64
# FL160Q03HA      float64
# FL160Q04HA      float64
# FL161Q01HA      float64
# FL161Q02HA      float64
# FL161Q03HA      float64
# FL162Q01HA      float64
# FL162Q02HA      float64
# FL162Q03HA      float64
# FL162Q04HA      float64
# FL162Q05HA      float64
# FL162Q06HA      float64
# FL163Q01HA      float64
# FL163Q02HA      float64
# FL163Q03HA      float64
# FL163Q04HA      float64
# FL163Q05HA      float64
# FL171Q01JA      float64
# FL171Q02JA      float64
# FL171Q03JA      float64
# FL171Q04JA      float64
# FL171Q05JA      float64
# FL171Q07JA      float64
# FL171Q08JA      float64
# FL171Q09JA      float64
# FL171Q10JA      float64
# FL171Q11JA      float64
# FL171Q12JA      float64
# FL169Q01HA      float64
# FL169Q05JA      float64
# FL169Q02HA      float64
# FL169Q06JA      float64
# FL169Q07JA      float64
# FL169Q03HA      float64
# FL169Q04HA      float64
# FL169Q08JA      float64
# FL169Q10JA      float64
# FL169Q11JA      float64
# FL172Q01JA      float64
# FL172Q03JA      float64
# FL172Q05JA      float64
# FL172Q06JA      float64
# IC170Q01JA      float64
# IC170Q02JA      float64
# IC170Q03JA      float64
# IC170Q04JA      float64
# IC170Q05JA      float64
# IC170Q06JA      float64
# IC170Q07JA      float64
# IC171Q01JA      float64
# IC171Q02JA      float64
# IC171Q03JA      float64
# IC171Q04JA      float64
# IC171Q05JA      float64
# IC171Q06JA      float64
# IC172Q01JA      float64
# IC172Q02JA      float64
# IC172Q03JA      float64
# IC172Q04JA      float64
# IC172Q05JA      float64
# IC172Q06JA      float64
# IC172Q07JA      float64
# IC172Q08JA      float64
# IC172Q09JA      float64
# IC173Q01JA      float64
# IC173Q02JA      float64
# IC173Q03JA      float64
# IC173Q04JA      float64
# IC174Q01JA      float64
# IC174Q02JA      float64
# IC174Q03JA      float64
# IC174Q04JA      float64
# IC174Q05JA      float64
# IC174Q06JA      float64
# IC174Q07JA      float64
# IC174Q08JA      float64
# IC174Q09JA      float64
# IC174Q10JA      float64
# IC175Q01JA      float64
# IC175Q02JA      float64
# IC175Q03JA      float64
# IC175Q05JA      float64
# IC176Q01JA      float64
# IC176Q02JA      float64
# IC176Q03JA      float64
# IC176Q04JA      float64
# IC176Q05JA      float64
# IC176Q06JA      float64
# IC176Q07JA      float64
# IC176Q08JA      float64
# IC184Q01JA      float64
# IC184Q02JA      float64
# IC184Q03JA      float64
# IC184Q04JA      float64
# IC177Q01JA      float64
# IC177Q02JA      float64
# IC177Q03JA      float64
# IC177Q04JA      float64
# IC177Q05JA      float64
# IC177Q06JA      float64
# IC177Q07JA      float64
# IC178Q01JA      float64
# IC178Q02JA      float64
# IC178Q03JA      float64
# IC178Q04JA      float64
# IC178Q05JA      float64
# IC178Q06JA      float64
# IC178Q07JA      float64
# IC179Q01JA      float64
# IC179Q02JA      float64
# IC179Q03JA      float64
# IC179Q04JA      float64
# IC179Q05JA      float64
# IC179Q06JA      float64
# IC180Q01JA      float64
# IC180Q02JA      float64
# IC180Q03JA      float64
# IC180Q04JA      float64
# IC180Q05JA      float64
# IC180Q06JA      float64
# IC180Q07JA      float64
# IC180Q08JA      float64
# IC181Q01JA      float64
# IC181Q02JA      float64
# IC181Q03JA      float64
# IC181Q04JA      float64
# IC182Q01JA      float64
# IC182Q02JA      float64
# IC182Q03JA      float64
# IC183Q01JA      float64
# IC183Q02JA      float64
# IC183Q03JA      float64
# IC183Q04JA      float64
# IC183Q05JA      float64
# IC183Q07JA      float64
# IC183Q08JA      float64
# IC183Q09JA      float64
# IC183Q10JA      float64
# IC183Q12JA      float64
# IC183Q13JA      float64
# IC183Q14JA      float64
# IC183Q15JA      float64
# IC183Q16JA      float64
# WB150Q01HA      float64
# WB151Q01HA      float64
# WB152Q01HA      float64
# WB153Q01HA      float64
# WB153Q02HA      float64
# WB153Q03HA      float64
# WB153Q04HA      float64
# WB153Q05HA      float64
# WB154Q01HA      float64
# WB154Q02HA      float64
# WB154Q03HA      float64
# WB154Q04HA      float64
# WB154Q05HA      float64
# WB154Q06HA      float64
# WB154Q07HA      float64
# WB154Q08HA      float64
# WB154Q09HA      float64
# WB155Q01HA      float64
# WB155Q02HA      float64
# WB155Q03HA      float64
# WB155Q04HA      float64
# WB155Q05HA      float64
# WB155Q06HA      float64
# WB155Q07HA      float64
# WB155Q08HA      float64
# WB155Q09HA      float64
# WB155Q10HA      float64
# WB156Q01HA      float64
# WB158Q01HA      float64
# WB160Q01HA      float64
# WB161Q01HA      float64
# WB162Q01HA      float64
# WB162Q02HA      float64
# WB162Q03HA      float64
# WB162Q04HA      float64
# WB162Q05HA      float64
# WB162Q06HA      float64
# WB162Q07HA      float64
# WB162Q08HA      float64
# WB162Q09HA      float64
# WB163Q01HA      float64
# WB163Q02HA      float64
# WB163Q03HA      float64
# WB163Q04HA      float64
# WB163Q05HA      float64
# WB163Q06HA      float64
# WB163Q07HA      float64
# WB163Q08HA      float64
# WB164Q01HA      float64
# WB165Q01HA      float64
# WB166Q01HA      float64
# WB166Q02HA      float64
# WB166Q03HA      float64
# WB166Q04HA      float64
# WB167Q01HA      float64
# WB168Q01HA      float64
# WB168Q02HA      float64
# WB168Q03HA      float64
# WB168Q04HA      float64
# WB171Q01HA      float64
# WB171Q02HA      float64
# WB171Q03HA      float64
# WB171Q04HA      float64
# WB172Q01HA      float64
# WB173Q01HA      float64
# WB173Q02HA      float64
# WB173Q03HA      float64
# WB173Q04HA      float64
# WB176Q01HA      float64
# WB177Q01HA      float64
# WB177Q02HA      float64
# WB177Q03HA      float64
# WB177Q04HA      float64
# WB032Q01NA      float64
# WB032Q02NA      float64
# WB031Q01NA      float64
# WB178Q01HA      float64
# WB178Q02HA      float64
# WB178Q03HA      float64
# WB178Q04HA      float64
# WB178Q05HA      float64
# WB178Q06HA      float64
# WB178Q07HA      float64
# PA001Q01TA      float64
# PA001Q02TA      float64
# PA001Q03TA      float64
# PA003Q01TA      float64
# PA003Q02TA      float64
# PA003Q03TA      float64
# PA003Q05IA      float64
# PA003Q18WA      float64
# PA003Q19WA      float64
# PA003Q20WA      float64
# PA003Q11JA      float64
# PA003Q12JA      float64
# PA003Q13JA      float64
# PA003Q14JA      float64
# PA003Q15JA      float64
# PA003Q16JA      float64
# PA003Q17JA      float64
# PA196Q01WA      float64
# PA196Q02WA      float64
# PA196Q03WA      float64
# PA196Q04WA      float64
# PA197Q01WA      float64
# PA197Q02WA      float64
# PA197Q03WA      float64
# PA197Q04WA      float64
# PA197Q05WA      float64
# PA008Q01TA      float64
# PA008Q02TA      float64
# PA008Q03TA      float64
# PA008Q04TA      float64
# PA008Q05TA      float64
# PA008Q06NA      float64
# PA008Q07NA      float64
# PA008Q08NA      float64
# PA008Q09NA      float64
# PA008Q10NA      float64
# PA009Q01NA      float64
# PA009Q02NA      float64
# PA009Q03NA      float64
# PA009Q04NA      float64
# PA009Q05NA      float64
# PA009Q06NA      float64
# PA009Q07NA      float64
# PA009Q08NA      float64
# PA009Q09NA      float64
# PA009Q10NA      float64
# PA009Q11NA      float64
# PA007Q01TA      float64
# PA007Q02TA      float64
# PA007Q03TA      float64
# PA007Q04TA      float64
# PA007Q05TA      float64
# PA007Q06TA      float64
# PA007Q07TA      float64
# PA007Q09NA      float64
# PA007Q11NA      float64
# PA007Q12NA      float64
# PA007Q13NA      float64
# PA007Q14NA      float64
# PA007Q15NA      float64
# PA005Q01TA      float64
# PA006Q01TA      float64
# PA006Q02TA      float64
# PA006Q03TA      float64
# PA006Q04TA      float64
# PA006Q05TA      float64
# PA006Q06TA      float64
# PA006Q07TA      float64
# PA006Q08TA      float64
# PA006Q09TA      float64
# PA006Q10TA      float64
# PA006Q11TA      float64
# PA006Q12HA      float64
# PA006Q13HA      float64
# PA006Q14HA      float64
# PA166Q01HA      float64
# PA167Q02HA      float64
# PA167Q03HA      float64
# PA167Q04HA      float64
# PA167Q05HA      float64
# PA183Q01JA      float64
# PA183Q02JA      float64
# PA183Q03JA      float64
# PA183Q04JA      float64
# PA183Q05JA      float64
# PA183Q06JA      float64
# PA183Q07JA      float64
# PA183Q08JA      float64
# PA018Q01NA      float64
# PA018Q02NA      float64
# PA018Q03NA      float64
# PA177Q01HA      float64
# PA177Q02HA      float64
# PA177Q03HA      float64
# PA177Q04HA      float64
# PA177Q05HA      float64
# PA177Q06HA      float64
# PA177Q07HA      float64
# PA177Q08HA      float64
# PA180Q01HA      float64
# PA182Q01HA      float64
# PA175Q01HA      float64
# PA175Q02HA      float64
# PA175Q03JA      float64
# PA175Q04JA      float64
# PA185Q01JA      float64
# PA185Q02JA      float64
# PA185Q03JA      float64
# PA185Q04JA      float64
# PA185Q05JA      float64
# PA185Q07JA      float64
# PA185Q08JA      float64
# PA185Q09JA      float64
# PA185Q10JA      float64
# PA186Q01JA      float64
# PA186Q02JA      float64
# PA186Q03JA      float64
# PA186Q04JA      float64
# PA186Q05JA      float64
# PA186Q06JA      float64
# PA186Q07JA      float64
# PA186Q08JA      float64
# PA187Q04JA      float64
# PA187Q06JA      float64
# PA188Q01JA      float64
# PA188Q02JA      float64
# PA188Q03JA      float64
# PA188Q04JA      float64
# PA188Q05JA      float64
# PA188Q06JA      float64
# PA188Q08JA      float64
# PA188Q09JA      float64
# PA188Q10JA      float64
# PA189Q01JA      float64
# PA189Q02JA      float64
# PA189Q03JA      float64
# PA189Q04JA      float64
# PA189Q05JA      float64
# PA189Q06JA      float64
# PA189Q09JA      float64
# PA189Q10JA      float64
# PA194Q01JA      float64
# PA195Q01JA      float64
# PA041Q01TA      float64
# PA042Q01TA      float64
# EFFORT1         float64
# EFFORT2         float64
# OCOD1            object
# OCOD2            object
# OCOD3            object
# PROGN            object
# AGE             float64
# GRADE           float64
# ISCEDP          float64
# IMMIG           float64
# COBN_S           object
# COBN_M           object
# COBN_F           object
# LANGN           float64
# REPEAT          float64
# MISSSC          float64
# SKIPPING        float64
# TARDYSD         float64
# EXERPRAC        float64
# STUDYHMW        float64
# WORKPAY         float64
# WORKHOME        float64
# EXPECEDU        float64
# MATHPREF        float64
# MATHEASE        float64
# MATHMOT         float64
# DURECEC         float64
# BSMJ            float64
# SISCO           float64
# RELATST         float64
# BELONG          float64
# BULLIED         float64
# FEELSAFE        float64
# SCHRISK         float64
# PERSEVAGR       float64
# CURIOAGR        float64
# COOPAGR         float64
# EMPATAGR        float64
# ASSERAGR        float64
# STRESAGR        float64
# EMOCOAGR        float64
# GROSAGR         float64
# INFOSEEK        float64
# FAMSUP          float64
# DISCLIM         float64
# TEACHSUP        float64
# COGACRCO        float64
# COGACMCO        float64
# EXPOFA          float64
# EXPO21ST        float64
# MATHEFF         float64
# MATHEF21        float64
# FAMCON          float64
# ANXMAT          float64
# MATHPERS        float64
# CREATEFF        float64
# CREATSCH        float64
# CREATFAM        float64
# CREATAS         float64
# CREATOOS        float64
# CREATOP         float64
# OPENART         float64
# IMAGINE         float64
# SCHSUST         float64
# LEARRES         float64
# PROBSELF        float64
# FAMSUPSL        float64
# FEELLAH         float64
# SDLEFF          float64
# MISCED          float64
# FISCED          float64
# HISCED          float64
# PAREDINT        float64
# BMMJ1           float64
# BFMJ2           float64
# HISEI           float64
# ICTRES          float64
# HOMEPOS         float64
# ESCS            float64
# FCFMLRTY        float64
# FLSCHOOL        float64
# FLMULTSB        float64
# FLFAMILY        float64
# ACCESSFP        float64
# FLCONFIN        float64
# FLCONICT        float64
# ACCESSFA        float64
# ATTCONFM        float64
# FRINFLFM        float64
# ICTSCH          float64
# ICTAVSCH        float64
# ICTHOME         float64
# ICTAVHOM        float64
# ICTQUAL         float64
# ICTSUBJ         float64
# ICTENQ          float64
# ICTFEED         float64
# ICTOUT          float64
# ICTWKDY         float64
# ICTWKEND        float64
# ICTREG          float64
# ICTINFO         float64
# ICTDISTR        float64
# ICTEFFIC        float64
# STUBMI          float64
# BODYIMA         float64
# SOCONPA         float64
# LIFESAT         float64
# PSYCHSYM        float64
# SOCCON          float64
# EXPWB           float64
# CURSUPP         float64
# PQMIMP          float64
# PQMCAR          float64
# PARINVOL        float64
# PQSCHOOL        float64
# PASCHPOL        float64
# ATTIMMP         float64
# PAREXPT         float64
# CREATHME        float64
# CREATACT        float64
# CREATOPN        float64
# CREATOR         float64
# W_FSTUWT        float64
# W_FSTURWT1      float64
# W_FSTURWT2      float64
# W_FSTURWT3      float64
# W_FSTURWT4      float64
# W_FSTURWT5      float64
# W_FSTURWT6      float64
# W_FSTURWT7      float64
# W_FSTURWT8      float64
# W_FSTURWT9      float64
# W_FSTURWT10     float64
# W_FSTURWT11     float64
# W_FSTURWT12     float64
# W_FSTURWT13     float64
# W_FSTURWT14     float64
# W_FSTURWT15     float64
# W_FSTURWT16     float64
# W_FSTURWT17     float64
# W_FSTURWT18     float64
# W_FSTURWT19     float64
# W_FSTURWT20     float64
# W_FSTURWT21     float64
# W_FSTURWT22     float64
# W_FSTURWT23     float64
# W_FSTURWT24     float64
# W_FSTURWT25     float64
# W_FSTURWT26     float64
# W_FSTURWT27     float64
# W_FSTURWT28     float64
# W_FSTURWT29     float64
# W_FSTURWT30     float64
# W_FSTURWT31     float64
# W_FSTURWT32     float64
# W_FSTURWT33     float64
# W_FSTURWT34     float64
# W_FSTURWT35     float64
# W_FSTURWT36     float64
# W_FSTURWT37     float64
# W_FSTURWT38     float64
# W_FSTURWT39     float64
# W_FSTURWT40     float64
# W_FSTURWT41     float64
# W_FSTURWT42     float64
# W_FSTURWT43     float64
# W_FSTURWT44     float64
# W_FSTURWT45     float64
# W_FSTURWT46     float64
# W_FSTURWT47     float64
# W_FSTURWT48     float64
# W_FSTURWT49     float64
# W_FSTURWT50     float64
# W_FSTURWT51     float64
# W_FSTURWT52     float64
# W_FSTURWT53     float64
# W_FSTURWT54     float64
# W_FSTURWT55     float64
# W_FSTURWT56     float64
# W_FSTURWT57     float64
# W_FSTURWT58     float64
# W_FSTURWT59     float64
# W_FSTURWT60     float64
# W_FSTURWT61     float64
# W_FSTURWT62     float64
# W_FSTURWT63     float64
# W_FSTURWT64     float64
# W_FSTURWT65     float64
# W_FSTURWT66     float64
# W_FSTURWT67     float64
# W_FSTURWT68     float64
# W_FSTURWT69     float64
# W_FSTURWT70     float64
# W_FSTURWT71     float64
# W_FSTURWT72     float64
# W_FSTURWT73     float64
# W_FSTURWT74     float64
# W_FSTURWT75     float64
# W_FSTURWT76     float64
# W_FSTURWT77     float64
# W_FSTURWT78     float64
# W_FSTURWT79     float64
# W_FSTURWT80     float64
# UNIT            float64
# WVARSTRR        float64
# PV1MATH         float64
# PV2MATH         float64
# PV3MATH         float64
# PV4MATH         float64
# PV5MATH         float64
# PV6MATH         float64
# PV7MATH         float64
# PV8MATH         float64
# PV9MATH         float64
# PV10MATH        float64
# PV1READ         float64
# PV2READ         float64
# PV3READ         float64
# PV4READ         float64
# PV5READ         float64
# PV6READ         float64
# PV7READ         float64
# PV8READ         float64
# PV9READ         float64
# PV10READ        float64
# PV1SCIE         float64
# PV2SCIE         float64
# PV3SCIE         float64
# PV4SCIE         float64
# PV5SCIE         float64
# PV6SCIE         float64
# PV7SCIE         float64
# PV8SCIE         float64
# PV9SCIE         float64
# PV10SCIE        float64
# PV1MCCR         float64
# PV2MCCR         float64
# PV3MCCR         float64
# PV4MCCR         float64
# PV5MCCR         float64
# PV6MCCR         float64
# PV7MCCR         float64
# PV8MCCR         float64
# PV9MCCR         float64
# PV10MCCR        float64
# PV1MCQN         float64
# PV2MCQN         float64
# PV3MCQN         float64
# PV4MCQN         float64
# PV5MCQN         float64
# PV6MCQN         float64
# PV7MCQN         float64
# PV8MCQN         float64
# PV9MCQN         float64
# PV10MCQN        float64
# PV1MCSS         float64
# PV2MCSS         float64
# PV3MCSS         float64
# PV4MCSS         float64
# PV5MCSS         float64
# PV6MCSS         float64
# PV7MCSS         float64
# PV8MCSS         float64
# PV9MCSS         float64
# PV10MCSS        float64
# PV1MCUD         float64
# PV2MCUD         float64
# PV3MCUD         float64
# PV4MCUD         float64
# PV5MCUD         float64
# PV6MCUD         float64
# PV7MCUD         float64
# PV8MCUD         float64
# PV9MCUD         float64
# PV10MCUD        float64
# PV1MPEM         float64
# PV2MPEM         float64
# PV3MPEM         float64
# PV4MPEM         float64
# PV5MPEM         float64
# PV6MPEM         float64
# PV7MPEM         float64
# PV8MPEM         float64
# PV9MPEM         float64
# PV10MPEM        float64
# PV1MPFS         float64
# PV2MPFS         float64
# PV3MPFS         float64
# PV4MPFS         float64
# PV5MPFS         float64
# PV6MPFS         float64
# PV7MPFS         float64
# PV8MPFS         float64
# PV9MPFS         float64
# PV10MPFS        float64
# PV1MPIN         float64
# PV2MPIN         float64
# PV3MPIN         float64
# PV4MPIN         float64
# PV5MPIN         float64
# PV6MPIN         float64
# PV7MPIN         float64
# PV8MPIN         float64
# PV9MPIN         float64
# PV10MPIN        float64
# PV1MPRE         float64
# PV2MPRE         float64
# PV3MPRE         float64
# PV4MPRE         float64
# PV5MPRE         float64
# PV6MPRE         float64
# PV7MPRE         float64
# PV8MPRE         float64
# PV9MPRE         float64
# PV10MPRE        float64
# SENWT           float64
# VER_DAT          object
# i               float64
# dtype: object

# %%
replacements = {
    'object' : 'varchar(20)',
    'float64' : 'float',
    'init64' : 'int',
    'datetime64': 'timestamp'
}

# %%
col_str = ", ".join("{} {}".format(n,d) for (n,d) in zip(pisa2022_df.columns, pisa2022_df.dtypes.replace(replacements)))
col_str
# Out:
# 'CNT varchar(20), CNTRYID float, CNTSCHID float, CNTSTUID float, CYC varchar(20), NatCen varchar(20), STRATUM varchar(20), SUBNATIO varchar(20), REGION float, OECD float, ADMINMODE float, LANGTEST_QQQ float, LANGTEST_COG float, LANGTEST_PAQ float, Option_CT float, Option_FL float, Option_ICTQ float, Option_WBQ float, Option_PQ float, Option_TQ float, Option_UH float, BOOKID float, ST001D01T float, ST003D02T float, ST003D03T float, ST004D01T float, ST250Q01JA float, ST250Q02JA float, ST250Q03JA float, ST250Q04JA float, ST250Q05JA float, ST250D06JA varchar(20), ST250D07JA varchar(20), ST251Q01JA float, ST251Q02JA float, ST251Q03JA float, ST251Q04JA float, ST251Q06JA float, ST251Q07JA float, ST251D08JA varchar(20), ST251D09JA varchar(20), ST253Q01JA float, ST254Q01JA float, ST254Q02JA float, ST254Q03JA float, ST254Q04JA float, ST254Q05JA float, ST254Q06JA float, ST255Q01JA float, ST256Q01JA float, ST256Q02JA float, ST256Q03JA float, ST256Q06JA float, ST256Q07JA float, ST256Q08JA float, ST256Q09JA float, ST256Q10JA float, ST230Q01JA float, ST005Q01JA float, ST006Q01JA float, ST006Q02JA float, ST006Q03JA float, ST006Q04JA float, ST006Q05JA float, ST007Q01JA float, ST008Q01JA float, ST008Q02JA float, ST008Q03JA float, ST008Q04JA float, ST008Q05JA float, ST258Q01JA float, ST259Q01JA float, ST259Q02JA float, ST019AQ01T float, ST019BQ01T float, ST019CQ01T float, ST021Q01TA float, ST022Q01TA float, ST226Q01JA float, ST125Q01NA float, ST126Q01TA float, ST127Q01TA float, ST127Q02TA float, ST127Q03TA float, ST260Q01JA float, ST260Q02JA float, ST260Q03JA float, ST261Q01JA float, ST261Q02JA float, ST261Q03JA float, ST261Q04JA float, ST261Q05JA float, ST261Q06JA float, ST261Q07JA float, ST261Q08JA float, ST261Q09JA float, ST261Q10JA float, ST261Q11JA float, ST062Q01TA float, ST062Q02TA float, ST062Q03TA float, ST267Q01JA float, ST267Q02JA float, ST267Q03JA float, ST267Q04JA float, ST267Q05JA float, ST267Q06JA float, ST267Q07JA float, ST267Q08JA float, ST034Q01TA float, ST
# 613742  86000.0  NON-OECD  ...  272.346  317.838  248.165  405.860  364.173
# 613743  86000.0  NON-OECD  ...  416.631  337.422  370.817  395.176  412.317
#
#         PV9MPRE  PV10MPRE    SENWT           VER_DAT      i
# 0       230.156   289.436  0.55561  03MAY23:10:11:25  218.0
# 1       347.626   352.269  0.76431  03MAY23:10:11:25  218.0
# 2       324.361   343.351  1.37877  03MAY23:10:11:25  218.0
# 3       275.860   227.466  1.49361  03MAY23:10:11:26  218.0
# 4       490.537   503.793  0.65249  03MAY23:10:11:26  218.0
# ...         ...       ...      ...               ...    ...
# 613739  395.329   278.263  0.71987  02MAY23:13:18:15  218.0
# 613740  254.340   233.187  0.65541  02MAY23:13:18:13  218.0
# 613741  408.986   460.542  0.67910  02MAY23:13:18:13  218.0
# 613742  346.663   341.668  0.68618  02MAY23:13:18:14  218.0
# 613743  390.490   439.211  0.67910  02MAY23:13:18:13  218.0
#
# [613744 rows x 1279 columns]

# %%
# Calculate NaN percentage for each column
nan_percentage = (pisa2022_df.isna().sum() / len(pisa2022_df)) * 100

# Calculate NaN percentage for each row
nan_percentage_rows = (pisa2022_df.isna().sum(axis=1) / len(pisa2022_df.columns)) * 100

# %%
# Delete columns with NaN percentage greater than 60%
columns_to_delete = nan_percentage[nan_percentage > 75].index
pisa2022_df.drop(columns=columns_to_delete, inplace=True)

"""# Delete rows with NaN percentage greater than 60%
rows_to_delete = nan_percentage_rows[nan_percentage_rows > 60].index
pisa2022_school_df.drop(index=rows_to_delete, inplace=True)"""
# Out:
# '# Delete rows with NaN percentage greater than 60%\nrows_to_delete = nan_percentage_rows[nan_percentage_rows > 60].index\npisa2022_school_df.drop(index=rows_to_delete, inplace=True)'

# %%
pisa2022_df = pisa2022_df.fillna(value=0)

# %% [markdown]
# 2022 PISA Score Dataset

# %%
###pisa2022_avr_scores_df  = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\Average_score.csv", encoding = "ISO-8859-1")
###pisa2022_avr_scores_df

# %% [markdown]
# 2022 PISA Math Scores

# %%
###pisa2022_math_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\math_score.csv",encoding = "ISO-8859-1")
###pisa2022_math_scores_df

# %% [markdown]
# 2022 PISA Science Scores

# %%
#pisa2022_sci_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\Science_score.csv", encoding = "ISO-8859-1")
###pisa2022_sci_scores_df

# %% [markdown]
# 2022 PISA Reading Scores

# %%
#pisa2022_read_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\Reading_score.csv", encoding = "ISO-8859-1")
###pisa2022_read_scores_df

# %%
#pisa2022_sci_scores_df.info()

# %% [markdown]
# ISO alpha-3 code list

# %%
if os.path.exists(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv"):
    os.remove(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv")

file_input = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\raw\country_codes.txt", "r")
file_output = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv", "w")

# Add a header
file_output.write("Code,Country/Region\n")

# Replace the space separator with a comma
for line in file_input:
    new_line = line[:3] + ',' + line[4:]
    file_output.write(new_line)

file_input.close()
file_output.close()

# %%
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv", "r")

for line in country_codes_file:
    if (line.count(',') > 1):
        print(line)

country_codes_file.close()
# Out:
# BOL,Bolivia, Plurinational State of
#
# COD,Congo, the Democratic Republic of the
#
# FSM,Micronesia, Federated States of
#
# IRN,Iran, Islamic Republic of
#
# KOR,Korea, Republic of
#
# MDA,Moldova, Republic of
#
# MKD,Macedonia, the former Yugoslav Republic of
#
# PRK,Korea, Democratic People's Republic of
#
# PSE,Palestinian Territory, Occupied
#
# SHN,Saint Helena, Ascension and Tristan da Cunha
#
# TAP,Taiwan, Province of China
#
# TZA,Tanzania, United Republic of
#
# VEN,Venezuela, Bolivarian Republic of
#
# VGB,Virgin Islands, British
#
# VIR,Virgin Islands, U.S.

# %%
# Open the file in read mode
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv", "r")

# Replace all instances of ", " with "-"
country_codes_data = country_codes_file.read()
country_codes_data = country_codes_data.replace(", ", " - ")

country_codes_file.close()

# Open the file again in write mode
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv", "w")
country_codes_file.write(country_codes_data)
country_codes_file.close()

# %% [markdown]
# CONSTRUCTED ISO 3166-1 ALPHA-3 CODE LIST

# %%
country_codes_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\pisa2022_analysis\StreamlitDev\data_file\data\country_codes.csv")

# %%
country_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Code            246 non-null    object
#  1   Country/Region  246 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %% [markdown]
# DATA PREPROCESSING
#
# Merging the 2022 PISA School Dataset and ISO  alpha-3 Code List

# %%
###pisa2022_df = pisa2022_school_df.merge(country_codes_df, left_on = "CNT", right_on = "Code", how = 'left')
###pisa2022_df

# %% [markdown]
# Check for null values in 'Country/Region'

# %%
pisa2022_df[pisa2022_df['Country/Region'].isnull()]['CNT'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\1stApril\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country/Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pisa2022_df[pisa2022_df['Country/Region'].isnull()]['CNT'].unique()
#
# File c:\Users\1stApril\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\1stApril\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Country/Region'

# %%
addl_codes = {"QAZ": "Azerbaijan",
              "TAP": "Taiwan",
              "KSV": "Kosovo",
              "QUR": "Ukraine"}

# %%
for code, country in addl_codes.items():
    pisa2022_df.loc[pisa2022_df['CNT'] == code, 'Country/Region'] = country
    
pisa2022_df
# Out:
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_19168\2071018841.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pisa2022_df.loc[pisa2022_df['CNT'] == code, 'Country/Region'] = country
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION      OECD  ...  PV5MPRE  PV6MPRE  PV7MPRE  PV8MPRE  PV9MPRE  \
# 0         800.0  NON-OECD  ...  219.817  331.017  223.752  305.671  230.156
# 1         800.0  NON-OECD  ...  320.452  284.836  364.565  304.044  347.626
# 2         800.0  NON-OECD  ...  285.901  289.896  338.469  316.296  324.361
# 3         800.0  NON-OECD  ...  327.793  165.575  246.156  238.322  275.860
# 4         800.0  NON-OECD  ...  539.850  461.793  514.465  510.462  490.537
# ...         ...       ...  ...      ...      ...      ...      ...      ...
# 613739  86000.0  NON-OECD  ...  271.135  386.969  376.271  368.287  395.329
# 613740  86000.0  NON-OECD  ...  232.583  179.328  233.470  203.001  254.340
# 613741  86000.0  NON-OECD  ...  432.586  387.329  456.236  424.790  408.986
# 613742  86000.0  NON-OECD  ...  317.838  248.165  405.860  364.173  346.663
# 613743  86000.0  NON-OECD  ...  337.422  370.817  395.176  412.317  390.490
#
#         PV10MPRE    SENWT           VER_DAT      i  Country/Region
# 0        289.436  0.55561  03MAY23:10:11:25  218.0             nan
# 1        352.269  0.76431  03MAY23:10:11:25  218.0             nan
# 2        343.351  1.37877  03MAY23:10:11:25  218.0             nan
# 3        227.466  1.49361  03MAY23:10:11:26  218.0             nan
# 4        503.793  0.65249  03MAY23:10:11:26  218.0             nan
# ...          ...      ...               ...    ...             ...
# 613739   278.263  0.71987  02MAY23:13:18:15  218.0             nan
# 613740   233.187  0.65541  02MAY23:13:18:13  218.0             nan
# 613741   460.542  0.67910  02MAY23:13:18:13  218.0             nan
# 613742   341.668  0.68618  02MAY23:13:18:14  218.0             nan
# 613743   439.211  0.67910  02MAY23:13:18:13  218.0             nan
#
# [613744 rows x 837 columns]

# %%
pisa2022_df['Country/Region'].isnull().values.any()
# Out:
# False

# %% [markdown]
# 2. Merging the 2022 PISA School Dataset, ISO  alpha-3 Code List, and 2022 PISA Scores Dataset

# %%
#pisa_school_only = set(pisa2022_school_df['Country/Region']) - set(pisa2022_avr_scores_df['Country/Region'])
#pisa_school_only

# %%
pisa_school_only_tokens = {}
excluded = ['of', 'the', '-', 'former', 'Federation', 'Republic', 'Occupied', 'Yugoslav' ]

for region in pisa2022_df:
    # Remove punctuation marks
    region_clean = region.replace('(', '')
    region_clean = region_clean.replace(')', '')
    region_clean = region_clean.replace(',', '')
    region_clean = region_clean.replace(',', '')
    
    pisa_school_only_tokens[region] = set()
    
    # Tokenize the country/region name into constituent words
    for token in region_clean.split():
        if token not in excluded:
            pisa_school_only_tokens[region].add(token)
            
pisa_school_only_tokens
# Out:
# {'CNT': {'CNT'},
#  'CNTRYID': {'CNTRYID'},
#  'CNTSCHID': {'CNTSCHID'},
#  'CNTSTUID': {'CNTSTUID'},
#  'CYC': {'CYC'},
#  'NatCen': {'NatCen'},
#  'STRATUM': {'STRATUM'},
#  'SUBNATIO': {'SUBNATIO'},
#  'REGION': {'REGION'},
#  'OECD': {'OECD'},
#  'ADMINMODE': {'ADMINMODE'},
#  'LANGTEST_QQQ': {'LANGTEST_QQQ'},
#  'LANGTEST_COG': {'LANGTEST_COG'},
#  'Option_ICTQ': {'Option_ICTQ'},
#  'Option_WBQ': {'Option_WBQ'},
#  'Option_PQ': {'Option_PQ'},
#  'Option_TQ': {'Option_TQ'},
#  'Option_UH': {'Option_UH'},
#  'BOOKID': {'BOOKID'},
#  'EXPECEDU': {'EXPECEDU'},
#  'MATHPREF': {'MATHPREF'},
#  'MATHEASE': {'MATHEASE'},
#  'MATHMOT': {'MATHMOT'},
#  'DURECEC': {'DURECEC'},
#  'BSMJ': {'BSMJ'},
#  'SISCO': {'SISCO'},
#  'RELATST': {'RELATST'},
#  'BELONG': {'BELONG'},
#  'BULLIED': {'BULLIED'},
#  'FEELSAFE': {'FEELSAFE'},
#  'SCHRISK': {'SCHRISK'},
#  'PERSEVAGR': {'PERSEVAGR'},
#  'CURIOAGR': {'CURIOAGR'},
#  'COOPAGR': {'COOPAGR'},
#  'EMPATAGR': {'EMPATAGR'},
#  'ASSERAGR': {'ASSERAGR'},
#  'STRESAGR': {'STRESAGR'},
#  'EMOCOAGR': {'EMOCOAGR'},
#  'INFOSEEK': {'INFOSEEK'},
#  'FAMSUP': {'FAMSUP'},
#  'DISCLIM': {'DISCLIM'},
#  'TEACHSUP': {'TEACHSUP'},
#  'COGACRCO': {'COGACRCO'},
#  'COGACMCO': {'COGACMCO'},
#  'EXPOFA': {'EXPOFA'},
#  'EXPO21ST': {'EXPO21ST'},
#  'MATHEFF': {'MATHEFF'},
#  'MATHEF21': {'MATHEF21'},
#  'FAMCON': {'FAMCON'},
#  'ANXMAT': {'ANXMAT'},
#  'MATHPERS': {'MATHPERS'},
#  'SCHSUST': {'SCHSUST'},
#  'LEARRES': {'LEARRES'},
#  'PROBSELF': {'PROBSELF'},
#  'FAMSUPSL': {'FAMSUPSL'},
#  'FEELLAH': {'FEELLAH'},
#  'SDLEFF': {'SDLEFF'},
#  'MISCED': {'MISCED'},
#  'FISCED': {'FISCED'},
#  'HISCED': {'HISCED'},
#  'PAREDINT': {'PAREDINT'},
#  'BMMJ1': {'BMMJ1'},
#  'BFMJ2': {'BFMJ2'},
#  'HISEI': {'HISEI'},
#  'ICTRES': {'ICTRES'},
#  'HOMEPOS': {'HOMEPOS'},
#  'ESCS': {'ESCS'},
#  'ICTSCH': {'ICTSCH'},
#  'ICTAVSCH': {'ICTAVSCH'},
#  'ICTHOME': {'ICTHOME'},
#  'ICTAVHOM': {'ICTAVHOM'},
#  'ICTQUAL': {'ICTQUAL'},
#  'ICTSUBJ': {'ICTSUBJ'},
#  'ICTENQ': {'ICTENQ'},
#  'ICTFEED': {'ICTFEED'},
#  'ICTOUT': {'ICTOUT'},
#  'ICTWKDY': {'ICTWKDY'},
#  'ICTWKEND': {'ICTWKEND'},
#  'ICTREG': {'ICTREG'},
#  'ICTINFO': {'ICTINFO'},
#  'ICTDISTR': {'ICTDISTR'},
#  'ICTEFFIC': {'ICTEFFIC'},
#  'W_FSTUWT': {'W_FSTUWT'},
#  'W_FSTURWT1': {'W_FSTURWT1'},
#  'W_FSTURWT2': {'W_FSTURWT2'},
#  'W_FSTURWT3': {'W_FSTURWT3'},
#  'W_FSTURWT4': {'W_FSTURWT4'},
#  'W_FSTURWT5': {'W_FSTURWT5'},
#  'W_FSTURWT6': {'W_FSTURWT6'},
#  'W_FSTURWT7': {'W_FSTURWT7'},
#  'W_FSTURWT64': {'W_FSTURWT64'},
#  'W_FSTURWT65': {'W_FSTURWT65'},
#  'W_FSTURWT66': {'W_FSTURWT66'},
#  'W_FSTURWT67': {'W_FSTURWT67'},
#  'W_FSTURWT68': {'W_FSTURWT68'},
#  'W_FSTURWT69': {'W_FSTURWT69'},
#  'W_FSTURWT70': {'W_FSTURWT70'},
#  'W_FSTURWT71': {'W_FSTURWT71'},
#  'W_FSTURWT72': {'W_FSTURWT72'},
#  'W_FSTURWT73': {'W_FSTURWT73'},
#  'W_FSTURWT74': {'W_FSTURWT74'},
#  'W_FSTURWT75': {'W_FSTURWT75'},
#  'W_FSTURWT76': {'W_FSTURWT76'},
#  'W_FSTURWT77': {'W_FSTURWT77'},
#  'W_FSTURWT78': {'W_FSTURWT78'},
#  'W_FSTURWT79': {'W_FSTURWT79'},
#  'W_FSTURWT80': {'W_FSTURWT80'},
#  'UNIT': {'UNIT'},
#  'WVARSTRR': {'WVARSTRR'},
#  'PV1MATH': {'PV1MATH'},
#  'PV2MATH': {'PV2MATH'},
#  'PV3MATH': {'PV3MATH'},
#  'PV4MATH': {'PV4MATH'},
#  'PV5MATH': {'PV5MATH'},
#  'PV6MATH': {'PV6MATH'},
#  'PV7MATH': {'PV7MATH'},
#  'PV8MATH': {'PV8MATH'},
#  'PV9MATH': {'PV9MATH'},
#  'PV10MATH': {'PV10MATH'},
#  'PV1READ': {'PV1READ'},
#  'PV2READ': {'PV2READ'},
#  'PV3READ': {'PV3READ'},
#  'PV4READ': {'PV4READ'},
#  'PV5READ': {'PV5READ'},
#  'PV6READ': {'PV6READ'},
#  'PV7READ': {'PV7READ'},
#  'PV8READ': {'PV8READ'},
#  'PV9READ': {'PV9READ'},
#  'PV10READ': {'PV10READ'},
#  'PV1SCIE': {'PV1SCIE'},
#  'PV2SCIE': {'PV2SCIE'},
#  'PV3SCIE': {'PV3SCIE'},
#  'PV4SCIE': {'PV4SCIE'},
#  'PV5SCIE': {'PV5SCIE'},
#  'PV6SCIE': {'PV6SCIE'},
#  'PV7SCIE': {'PV7SCIE'},
#  'PV8SCIE': {'PV8SCIE'},
#  'PV9SCIE': {'PV9SCIE'},
#  'PV10SCIE': {'PV10SCIE'},
#  'PV1MCCR': {'PV1MCCR'},
#  'PV2MCCR': {'PV2MCCR'},
#  'PV3MCCR': {'PV3MCCR'},
#  'PV4MCCR': {'PV4MCCR'},
#  'PV5MCCR': {'PV5MCCR'},
#  'PV6MCCR': {'PV6MCCR'},
#  'PV7MCCR': {'PV7MCCR'},
#  'PV8MCCR': {'PV8MCCR'},
#  'PV9MCCR': {'PV9MCCR'},
#  'PV10MCCR': {'PV10MCCR'},
#  'PV1MCQN': {'PV1MCQN'},
#  'PV2MCQN': {'PV2MCQN'},
#  'PV3MCQN': {'PV3MCQN'},
#  'PV4MCQN': {'PV4MCQN'},
#  'PV5MCQN': {'PV5MCQN'},
#  'PV6MCQN': {'PV6MCQN'},
#  'PV7MCQN': {'PV7MCQN'},
#  'PV8MCQN': {'PV8MCQN'},
#  'PV9MCQN': {'PV9MCQN'},
#  'PV10MCQN': {'PV10MCQN'},
#  'PV1MCSS': {'PV1MCSS'},
#  'PV2MCSS': {'PV2MCSS'},
#  'PV3MCSS': {'PV3MCSS'},
#  'PV4MCSS': {'PV4MCSS'},
#  'PV5MCSS': {'PV5MCSS'},
#  'PV6MCSS': {'PV6MCSS'},
#  'PV7MCSS': {'PV7MCSS'},
#  'PV8MCSS': {'PV8MCSS'},
#  'PV9MCSS': {'PV9MCSS'},
#  'PV10MCSS': {'PV10MCSS'},
#  'PV1MCUD': {'PV1MCUD'},
#  'PV2MCUD': {'PV2MCUD'},
#  'PV3MCUD': {'PV3MCUD'},
#  'PV4MCUD': {'PV4MCUD'},
#  'PV5MCUD': {'PV5MCUD'},
#  'PV6MCUD': {'PV6MCUD'},
#  'PV7MCUD': {'PV7MCUD'},
#  'PV8MCUD': {'PV8MCUD'},
#  'PV9MCUD': {'PV9MCUD'},
#  'PV10MCUD': {'PV10MCUD'},
#  'PV1MPEM': {'PV1MPEM'},
#  'PV2MPEM': {'PV2MPEM'},
#  'PV3MPEM': {'PV3MPEM'},
#  'PV4MPEM': {'PV4MPEM'},
#  'PV5MPEM': {'PV5MPEM'},
#  'PV6MPEM': {'PV6MPEM'},
#  'PV7MPEM': {'PV7MPEM'},
#  'PV8MPEM': {'PV8MPEM'},
#  'PV9MPEM': {'PV9MPEM'},
#  'PV10MPEM': {'PV10MPEM'},
#  'PV1MPFS': {'PV1MPFS'},
#  'PV2MPFS': {'PV2MPFS'},
#  'PV3MPFS': {'PV3MPFS'},
#  'PV4MPFS': {'PV4MPFS'},
#  'PV5MPFS': {'PV5MPFS'},
#  'PV6MPFS': {'PV6MPFS'},
#  'PV7MPFS': {'PV7MPFS'},
#  'PV8MPFS': {'PV8MPFS'},
#  'PV9MPFS': {'PV9MPFS'},
#  'PV10MPFS': {'PV10MPFS'},
#  'PV1MPIN': {'PV1MPIN'},
#  'PV2MPIN': {'PV2MPIN'},
#  'PV3MPIN': {'PV3MPIN'},
#  'PV4MPIN': {'PV4MPIN'},
#  'PV5MPIN': {'PV5MPIN'},
#  'PV6MPIN': {'PV6MPIN'},
#  'PV7MPIN': {'PV7MPIN'},
#  'PV8MPIN': {'PV8MPIN'},
#  'PV9MPIN': {'PV9MPIN'},
#  'PV10MPIN': {'PV10MPIN'},
#  'PV1MPRE': {'PV1MPRE'},
#  'PV2MPRE': {'PV2MPRE'},
#  'PV3MPRE': {'PV3MPRE'},
#  'PV4MPRE': {'PV4MPRE'},
#  'PV5MPRE': {'PV5MPRE'},
#  'PV6MPRE': {'PV6MPRE'},
#  'PV7MPRE': {'PV7MPRE'},
#  'PV8MPRE': {'PV8MPRE'},
#  'PV9MPRE': {'PV9MPRE'},
#  'PV10MPRE': {'PV10MPRE'},
#  'SENWT': {'SENWT'},
#  'VER_DAT': {'VER_DAT'},
#  'i': {'i'},
#  'Country/Region': {'Country/Region'}}

# %%
###pisa_school_only_tokens['Slovak Republic'].add('Slovak Republic')


###pisa_school_only_tokens

# %%
"""pisa2022_avr_scores_only = set(pisa2022_avr_scores_df['Country/Region']) - set(pisa2022_df['Country/Region'])
candidates = {}

for pisa_school_region, tokens in pisa_school_only_tokens.items():
    for token in tokens:
        for pisa_scores_region in pisa2022_avr_scores_only:
            if token in pisa_scores_region:
                candidates[pisa_school_region] = pisa_scores_region
            
candidates"""

# %%
"""pisa_scores_only = set(pisa2022_avr_scores_df['Country/Region']) - set(pisa2022_df['Country/Region'])
candidates = {}

for pisa_school_region, tokens in pisa_school_only_tokens.items():
    for token in tokens:
        for pisa_scores_region in pisa_scores_only:
            if token in pisa_scores_region:
                candidates[pisa_school_region] = pisa_scores_region
            
candidates"""

# %%
for pisa_school_region, pisa_scores_region in candidates.items():
    pisa2022_df.loc[pisa2022_df['Country/Region'] == pisa_school_region, 'Country/Region'] = pisa_scores_region
    
pisa2022_df

# %%
##df_pisa2022 = pisa2022_school_df.merge(pisa2022_avr_scores_df, left_on = 'Country/Region', right_on = 'Country/Region', how = 'left')

#df_pisa2022

# %%
slovak_data = pisa2022_school_df[pisa2022_school_df['Country/Region'].str.contains('Cambodia', case=False)]

# %%
unique_countries = pisa2022_school_df['Country/Region'].nunique()
unique_countries

# %%
pisa2022_school_df.to_csv('pisa2022.csv', index=False)

# %%
asdsadad =

# %% [markdown]
# Math Literacy

# %%
df_pisa2022[['PV1MATH','PV2MATH','PV3MATH', 'PV4MATH', 'PV5MATH','PV6MATH','PV7MATH','PV8MATH', 'PV9MATH', 'PV10MATH']].describe()
df_pisa2022['Avg_Math_Literacy'] = df_pisa2022[['PV1MATH','PV2MATH','PV3MATH', 'PV4MATH', 'PV5MATH','PV6MATH','PV7MATH','PV8MATH', 'PV9MATH', 'PV10MATH']].mean(axis=1)

# %%
df_pisa2022[['PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE','PV6SCIE','PV7SCIE','PV8SCIE','PV9SCIE','PV10SCIE']].describe()
df_pisa2022['Avg_Scientific_Literacy'] = df_pisa2022[['PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE','PV6SCIE','PV7SCIE','PV8SCIE','PV9SCIE','PV10SCIE']].mean(axis=1)

# %%
df_pisa2022[['PV1READ','PV2READ','PV3READ', 'PV4READ', 'PV5READ','PV6READ','PV7READ','PV8READ', 'PV9READ', 'PV10READ']].describe()
df_pisa2022['Avg_Reading_Literacy'] = df_pisa2022[['PV1READ','PV2READ','PV3READ', 'PV4READ', 'PV5READ','PV6READ','PV7READ','PV8READ', 'PV9READ', 'PV10READ']].mean(axis=1)

# %%
df_pisa2022['Overall_Literacy'] = df_pisa2022[['Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy']].mean(axis=1)
df_pisa2022[['Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy','Overall_Literacy']];

# %%
pisa_analysis_df = df_pisa2022[['CNTSCHID','CNTSTUID', 'Country/Region', 'OECD', 'ST001D01T','ST004D01T','ST250Q04JA','ST250Q05JA','ST307Q10JA','ST034Q06TA','ST294Q02JA','HISCED','Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy','Overall_Literacy', 'Average_Score']]
pisa_analysis_df

# %%
pisa_analysis_df.rename(columns = {'CNTSCHID':'School_ID',
                          'CNTSTUID':'Student_ID',
                          'ST001D01T' : 'Student_Grade',
                          'ST004D01T' : 'Gender',
                          'ST250Q04JA' : 'Smartphone_with_internet',
                          'ST250Q05JA' : 'Internet_access',
                          'ST307Q10JA' : 'Perseverance_Give_up_easily',
                          'ST034Q06TA' : 'Feel_lonely_at_school',  
                          'ST294Q02JA' : 'Study_for_school_or_homework',
                          'HISCED'  : 'Highest_educational_level_parents'
                          }, inplace = True)
pisa_analysis_df

# %%
pisa_analysis_df.isnull().sum().sort_values(ascending=False)/613744*100;

# %%
pisa_analysis_df.isnull().sum().sort_values(ascending=False);

# %%
pisa_analysis_df['Study_for_school_or_homework'].unique()

# %%
pisa_analysis_df['OECD'].replace({0: 'NON-OECD', 1: 'OECD'}, inplace=True)
pisa_analysis_df['Gender'].replace({1: 'Female', 2: 'Male'}, inplace=True)
pisa_analysis_df['Smartphone_with_internet'].replace({1: 'Yes', 2: 'No'}, inplace=True)
pisa_analysis_df['Internet_access'].replace({1: 'Yes', 2: 'No'}, inplace=True)
pisa_analysis_df['Perseverance_Give_up_easily'].replace({'Strongly disagree': 'Strongly Disagree', 2: 'Disagree', 3: 'Neither agree nor disagree', 4: 'Agree', 5: 'Strongly Agree'}, inplace=True)
pisa_analysis_df['Feel_lonely_at_school'].replace({1: 'Strongly Agree', 2: 'Agree', 3: 'Disagree', 'Strongly disagreeree': 'Strongly Disagree'}, inplace=True)
pisa_analysis_df['Study_for_school_or_homework'].replace({1: '0 days', 2: '1 days', 3: '2 days', 4: '3 days', 5: '4 days', 6: '5 or more days'}, inplace=True)

# %%
df_pisa2022_final = pisa_analysis_df.dropna()
df_pisa2022_final.shape

# %%
print('The cleaned dataframe is composed of only',(203378)/613744 *100,'% of the original dataset.')

# %%
df_pisa2022_final

# %% [markdown]
# Fixing datatype

# %%
df_pisa2022_final['OECD'] = df_pisa2022_final.OECD.astype('category')
df_pisa2022_final['OECD'].dtypes

# %%
df_pisa2022_final['Gender'] = df_pisa2022_final.Gender.astype('category')
df_pisa2022_final['Student_Grade'] = df_pisa2022_final.Student_Grade.astype('float64')
df_pisa2022_final['Perseverance_Give_up_easily'] = df_pisa2022_final.Perseverance_Give_up_easily.astype('category')
df_pisa2022_final['Smartphone_with_internet'] = df_pisa2022_final.Smartphone_with_internet.astype('category')
df_pisa2022_final['Internet_access'] = df_pisa2022_final.Internet_access.astype('category')
df_pisa2022_final['Feel_lonely_at_school'] = df_pisa2022_final.Feel_lonely_at_school.astype('category')
df_pisa2022_final['Study_for_school_or_homework'] = df_pisa2022_final.Study_for_school_or_homework.astype('category')

# %%
df_pisa2022_final.info()

# %%
plt.figure(figsize=(15,16))
sb.countplot(data=df_pisa2022_final, y= 'Country/Region', color='darkblue', order = df_pisa2022_final['Country/Region'].value_counts(ascending=False).index);

# %%
pisa2022_df.to_csv('pisa2022.csv', index=False)
